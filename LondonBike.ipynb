# %% [markdown]
# <a href="https://colab.research.google.com/github/Roc0n/DataScienca-BootCamp/blob/main/LondonBike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.0.3'

# %%
df = pd.read_csv('london_bike.csv')
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df = df.set_index('timestamp')

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0
# ...                         ...         ...     ...
# 2017-01-03 19:00:00         0.0         0.0     3.0
# 2017-01-03 20:00:00         0.0         0.0     3.0
# 2017-01-03 21:00:00         0.0         0.0     3.0
# 2017-01-03 22:00:00         0.0         0.0     3.0
# 2017-01-03 23:00:00         0.0         0.0     3.0
#
# [17414 rows x 9 columns]

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %%
df_is_holyday =  df['is_holiday']
df_is_holyday
# Out:
# timestamp
# 2015-01-04 00:00:00    0.0
# 2015-01-04 01:00:00    0.0
# 2015-01-04 02:00:00    0.0
# 2015-01-04 03:00:00    0.0
# 2015-01-04 04:00:00    0.0
#                       ...
# 2017-01-03 19:00:00    0.0
# 2017-01-03 20:00:00    0.0
# 2017-01-03 21:00:00    0.0
# 2017-01-03 22:00:00    0.0
# 2017-01-03 23:00:00    0.0
# Name: is_holiday, Length: 17414, dtype: float64

# %%
df['is_weekend'].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

apple.info()
amazon.info()
google.info()
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2024-04-25 to 2019-04-29
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1258 non-null   float64
#  1   High    1258 non-null   float64
#  2   Low     1258 non-null   float64
#  3   Close   1258 non-null   float64
#  4   Volume  1258 non-null   float64
# dtypes: float64(5)
# memory usage: 59.0 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2024-04-25 to 2019-04-29
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1258 non-null   float64
#  1   High    1258 non-null   float64
#  2   Low     1258 non-null   float64
#  3   Close   1258 non-null   float64
#  4   Volume  1258 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.0 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2024-04-25 to 2019-04-29
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1258 non-null   float64
#  1   High    1258 non-null   float64
#  2   Low     1258 non-null   float64
#  3   Close   1258 non-null   float64
#  4   Volume  1258 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.0 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1249 entries, 2024-04-25 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1249 non-null   float64
#  1   High    1249 non-null   float64
#  2   Low     1249 non-null   float64
#  3   Close   1249 non-null   float64
#  4   Volume  1249 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.5 KB

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
apple
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2024-04-25    169.5250    170.6100   168.1511     169.8900  5.055833e+07
# 2024-04-24    166.5400    169.3000   166.2100     169.0200  4.825184e+07
# 2024-04-23    165.3500    167.0500   164.9200     166.9000  4.953776e+07
# 2024-04-22    165.5150    167.2600   164.7700     165.8400  4.811644e+07
# 2024-04-19    166.2100    166.4000   164.0750     164.9300  6.776782e+07
# ...                ...         ...        ...          ...           ...
# 2019-05-03     51.1061     51.3334    50.9476      51.3125  8.621501e+07
# 2019-05-02     50.8518     51.5288    50.4371      50.6834  1.320368e+08
# 2019-05-01     50.8598     52.1768    50.7014      51.0174  2.675181e+08
# 2019-04-30     49.2059     49.2916    48.2509      48.6276  1.920322e+08
# 2019-04-29     49.5339     49.9138    49.3994      49.5827  9.163053e+07
#
# [1258 rows x 5 columns]

# %%
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
amazon
# Out:
#             amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume
# Date
# 2024-04-25     169.6800     173.9200    166.3200      173.6700       49249390
# 2024-04-24     179.9400     180.3230    176.1800      176.5900       34185109
# 2024-04-23     178.0800     179.9300    175.9750      179.5400       37046519
# 2024-04-22     176.9400     178.8700    174.5600      177.2300       37924890
# 2024-04-19     178.7400     179.0000    173.4400      174.6200       55944410
# ...                 ...          ...         ...           ...            ...
# 2019-05-03      97.4500      98.2200     96.8000       98.1230      127631280
# 2019-05-02      95.6665      96.0775     94.0935       95.0410       79258300
# 2019-05-01      96.6545      97.1820     95.5275       95.5760       62339280
# 2019-04-30      96.5050      96.7855     95.3475       96.3260       70120140
# 2019-04-29      97.4500      97.8170     96.7045       96.9215       80425100
#
# [1258 rows x 5 columns]

# %%
google.columns = ['google_' + col.lower() for col in google.columns]
google
# Out:
#             google_open  google_high  google_low  google_close  google_volume
# Date
# 2024-04-25     151.3300     156.4900    150.8700      156.0000       57109730
# 2024-04-24     157.4900     159.5650    157.1650      159.1300       22779112
# 2024-04-23     156.9600     158.9700    156.2800      158.2600       21151568
# 2024-04-22     154.3100     157.6400    154.0600      156.2800       26446206
# 2024-04-19     156.2000     156.3600    152.3000      154.1100       32586602
# ...                 ...          ...         ...           ...            ...
# 2019-05-03      58.8705      59.5700     58.6775       59.4775       41587520
# 2019-05-02      58.6300      58.9690     57.9165       58.3255       45097800
# 2019-05-01      59.8750      59.9625     58.5840       58.6660       74340360
# 2019-04-30      59.5315      60.0490     59.1500       59.9480      133177100
# 2019-04-29      64.0255      64.8490     63.5855       64.8100       72367240
#
# [1258 rows x 5 columns]

# %%
uber.columns = ['uber_' + col.lower() for col in uber.columns]
uber
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-04-25      67.86      70.29    67.380       69.31     20545159
# 2024-04-24      70.15      70.22    67.365       69.36     27515596
# 2024-04-23      70.02      71.14    69.620       70.80     16814207
# 2024-04-22      70.48      70.89    68.480       68.98     26804899
# 2024-04-19      71.15      71.15    68.380       69.21     23169861
# ...               ...        ...       ...         ...          ...
# 2019-05-16      41.48      44.06    41.250       43.00     38115524
# 2019-05-15      39.37      41.88    38.950       41.29     36086065
# 2019-05-14      38.31      39.96    36.850       39.96     46661147
# 2019-05-13      38.79      39.24    36.080       37.10     79442420
# 2019-05-10      42.00      45.00    41.060       41.57    186322536
#
# [1249 rows x 5 columns]

# %%
df = pd.concat(objs = [apple, amazon, google, uber], axis=1)

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')
df.describe()
# Out:
#        apple_open  apple_high  apple_low  apple_close  apple_volume  \
# count     1258.00     1258.00    1258.00      1258.00       1258.00
# mean       130.67      132.14     129.30       130.79   99042035.91
# std         44.00       44.33      43.65        44.01   53343864.35
# min         42.68       43.28      41.42        42.15   24048344.00
# 25%         95.58       97.17      94.70        95.62   64580098.11
# 50%        142.21      143.60     140.40       142.19   85888732.86
# 75%        167.38      169.18     165.78       167.28  116476747.38
# max        198.02      199.62     197.00       198.11  434708544.96
#
#        amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# count      1258.00      1258.00     1258.00       1258.00        1258.00
# mean        133.08       134.69      131.36        133.05    72372555.48
# std          30.97        31.20       30.66         30.90    32806270.90
# min          82.08        83.48       81.30         81.82    17626740.00
# 25%         100.59       101.79       99.01        100.51    51029915.50
# 50%         134.81       136.71      133.52        135.01    63516590.00
# 75%         160.76       162.55      159.05        161.06    84801067.75
# max         187.72       189.77      185.51        189.05   311345660.00
#
#        google_open  google_high  google_low  google_close  google_volume  \
# count      1258.00      1258.00     1258.00       1258.00        1258.00
# mean        103.74       104.93      102.63        103.81    33649997.83
# std          29.90        30.16       29.62         29.90    14981814.21
# min          52.22        52.50       50.44         51.94     9312760.00
# 25%          74.64        75.53       74.05         74.93    24213810.25
# 50%         105.00       106.40      104.00        105.29    29879044.50
# 75%         131.62       133.26      130.02        131.86    37748297.25
# max         158.86       160.22      157.16        159.41   133177100.00
#
#        uber_open  uber_high  uber_low  uber_close  uber_volume
# count    1249.00    1249.00   1249.00     1249.00      1249.00
# mean       40.53      41.30     39.72       40.52  24980089.00
# std        12.75      12.84     12.62       12.72  18353110.36
# min        15.96      17.80     13.71       14.82   3380003.00
# 25%        31.04      31.78     30.46       31.12  15676273.00
# 50%        37.82      38.57     36.96       37.66  20983925.00
# 75%        46.87      47.65     46.19       46.96  29364741.00
# max        81.94      82.14     80.79       81.39 364261230.00

# %%
closes = [col.lower() for col in df.columns if col.endswith('close') ]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes]
# Out:
#             apple_close  amazon_close  google_close  uber_close
# Date
# 2019-04-29        49.58         96.92         64.81         NaN
# 2019-04-30        48.63         96.33         59.95         NaN
# 2019-05-01        51.02         95.58         58.67         NaN
# 2019-05-02        50.68         95.04         58.33         NaN
# 2019-05-03        51.31         98.12         59.48         NaN
# ...                 ...           ...           ...         ...
# 2024-04-19       164.93        174.62        154.11       69.21
# 2024-04-22       165.84        177.23        156.28       68.98
# 2024-04-23       166.90        179.54        158.26       70.80
# 2024-04-24       169.02        176.59        159.13       69.36
# 2024-04-25       169.89        173.67        156.00       69.31
#
# [1258 rows x 4 columns]

# %% [markdown]
# ### Metoda append

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-04-25      67.86      70.29     67.38       69.31     20545159
# 2024-04-24      70.15      70.22     67.36       69.36     27515596
# 2024-04-23      70.02      71.14     69.62       70.80     16814207
# 2024-04-22      70.48      70.89     68.48       68.98     26804899
# 2024-04-19      71.15      71.15     68.38       69.21     23169861

# %%
uber_6 = uber[uber.index.month == 6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2023-06-30      43.11      43.43     42.92       43.17     17589240
# 2023-06-29      44.09      44.28     42.11       42.58     28595285
# 2023-06-28      43.50      45.24     43.32       44.24     28187374
# 2023-06-27      44.69      44.83     43.75       43.83     29652066
# 2023-06-26      43.75      45.04     43.68       44.42     33692974
# ...               ...        ...       ...         ...          ...
# 2019-06-07      44.92      45.67     44.13       44.16     12654670
# 2019-06-06      45.00      45.75     44.28       44.92     16403691
# 2019-06-05      42.87      45.66     42.50       45.00     28609604
# 2019-06-04      42.56      42.88     40.70       42.75     23432141
# 2019-06-03      40.74      41.85     40.24       41.25     16605261
#
# [106 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month == 7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2023-07-31      48.85      49.49     48.15       49.46     38736789
# 2023-07-28      47.14      48.43     46.71       48.14     17154631
# 2023-07-27      48.00      48.09     46.35       46.61     17991953
# 2023-07-26      47.05      47.55     46.62       47.31     16666161
# 2023-07-25      47.20      47.73     46.93       47.17     14188200
# ...               ...        ...       ...         ...          ...
# 2019-07-08      43.59      43.85     42.75       42.95      9304101
# 2019-07-05      44.31      44.55     43.01       43.53      8239452
# 2019-07-03      44.00      44.46     43.79       44.23      3380003
# 2019-07-02      44.55      44.68     43.75       44.00     11881274
# 2019-07-01      46.98      47.04     44.06       44.27     17739998
#
# [105 rows x 5 columns]

# %%
uber_6_7 = uber_6.append(uber_7)
uber_6_7
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-aae1becbefc8> in <cell line: 1>()
# ----> 1 uber_6_7 = uber_6.append(uber_7)
#       2 uber_6_7
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'
